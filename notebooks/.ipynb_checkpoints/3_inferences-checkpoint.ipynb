# %% [markdown]
# # Setting Up for Inference

# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
# %cd C:/Users/MD. REZUWAN HASAN/Desktop/Jupyter Notebooks/Master Course BD/Week 9/Own Practice/
# Out:
# C:\Users\MD. REZUWAN HASAN\Desktop\Jupyter Notebooks\Master Course BD\Week 9\Own Practice

# %%
version = 3
img_path = 'test_images'

# %%
model_path = f'models/parrot-recognizer-v{version}.pkl'

model = load_learner(model_path)

# %% [markdown]
# # Inference 1
#
# **Target:** hyacinth macaw

# %%
img = Image.open(f'{img_path}/unknown_00.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/unknown_00.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('hyacinth macaw',
#  tensor(20),
#  tensor([6.4248e-11, 7.7348e-12, 2.6990e-11, 4.0721e-07, 1.2634e-10, 2.1223e-12,
#          6.9655e-12, 7.5923e-12, 1.2745e-11, 1.4457e-10, 5.9834e-14, 1.3010e-12,
#          8.0771e-14, 1.4527e-08, 1.1881e-11, 4.2986e-12, 5.1523e-10, 4.4012e-15,
#          7.0788e-10, 1.1531e-12, 1.0000e+00, 1.2618e-10, 7.7911e-13, 3.3082e-12,
#          1.5116e-12, 1.6932e-09, 1.8992e-08, 2.0635e-11, 3.7872e-11, 1.6257e-11,
#          2.6602e-13, 2.3032e-13, 1.2242e-11, 1.2893e-12, 1.9091e-12, 1.9924e-12,
#          9.5426e-11, 2.0422e-10, 2.8604e-12, 1.4323e-10, 3.4740e-13, 6.4071e-07,
#          4.6938e-12, 1.5706e-10, 9.8868e-10, 5.3116e-14, 9.7487e-10, 6.4678e-11,
#          6.2680e-12]))

# %% [markdown]
# # Inference 2
#
# **Target:** eclectus parrot

# %%
img = Image.open(f'{img_path}/unknown_01.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x80>

# %%
model.predict(f'{img_path}/unknown_01.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('eclectus parrot',
#  tensor(13),
#  tensor([2.1027e-09, 1.2441e-07, 4.7862e-08, 3.7638e-10, 5.0439e-11, 6.0982e-09,
#          2.5668e-11, 4.9149e-11, 1.9834e-12, 1.2969e-10, 6.6469e-11, 1.9863e-11,
#          1.9834e-11, 9.9995e-01, 1.4520e-09, 1.5342e-09, 1.0580e-10, 8.3322e-08,
#          7.2340e-08, 1.4013e-09, 1.0676e-07, 2.1363e-08, 8.6182e-10, 7.6055e-08,
#          5.1676e-09, 4.8055e-10, 1.3026e-07, 1.4478e-06, 5.0550e-06, 1.0791e-10,
#          2.2078e-08, 1.8364e-09, 8.6631e-10, 2.8088e-09, 3.2730e-11, 1.6986e-09,
#          2.0241e-09, 4.3419e-05, 1.1899e-10, 7.9487e-10, 1.9777e-09, 1.1103e-09,
#          2.0006e-10, 2.7203e-09, 8.3383e-11, 4.2232e-07, 5.1469e-10, 4.5383e-11,
#          4.1034e-09]))

# %% [markdown]
# # Inference 3
# **Target:** cockatiels

# %%
img = Image.open(f'{img_path}/unknown_02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=102x128>

# %%
model.predict(f'{img_path}/unknown_02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('cockatiels',
#  tensor(10),
#  tensor([2.8408e-08, 6.1760e-08, 1.3264e-05, 3.3668e-09, 8.1347e-10, 3.4354e-06,
#          6.0331e-08, 6.8093e-07, 1.2325e-09, 8.1363e-11, 9.9996e-01, 1.7625e-06,
#          8.1310e-08, 2.4304e-09, 8.1044e-06, 8.5803e-09, 2.8885e-10, 6.9032e-08,
#          1.3569e-06, 9.4748e-10, 2.4702e-09, 2.5886e-08, 4.1093e-07, 7.1209e-06,
#          1.2575e-07, 4.0161e-09, 2.4508e-07, 3.2406e-06, 3.2778e-08, 2.6537e-08,
#          1.0881e-08, 3.7868e-09, 5.1121e-08, 3.6748e-07, 7.6122e-10, 5.2655e-11,
#          2.0037e-07, 1.8920e-07, 7.5992e-08, 6.0719e-08, 4.9137e-09, 1.2492e-08,
#          1.5211e-08, 1.7180e-09, 2.0256e-09, 7.5872e-08, 7.9362e-07, 4.2933e-09,
#          1.7420e-07]))

# %% [markdown]
# # Inference 4
# **Target:** blue-and-yellow macaw

# %%
img = Image.open(f'{img_path}/unknown_03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x101>

# %%
model.predict(f'{img_path}/unknown_03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('blue-and-yellow macaw',
#  tensor(3),
#  tensor([1.8056e-08, 9.0746e-08, 4.7187e-07, 9.9980e-01, 5.4933e-09, 6.3215e-08,
#          1.2264e-07, 1.8631e-05, 1.2728e-04, 9.4765e-06, 6.1036e-08, 4.2413e-08,
#          8.6259e-09, 3.7018e-09, 3.3778e-08, 4.5977e-06, 3.4785e-06, 5.9212e-09,
#          7.4350e-08, 1.9658e-07, 1.9056e-06, 7.6339e-09, 2.3995e-08, 2.5762e-09,
#          7.0620e-08, 1.2656e-06, 2.7837e-08, 2.2856e-09, 1.4809e-08, 2.8128e-07,
#          9.7540e-08, 7.2638e-07, 1.3939e-09, 2.3209e-09, 2.6936e-08, 1.8303e-06,
#          3.4735e-08, 2.9637e-08, 1.2461e-07, 1.4308e-05, 1.4954e-07, 3.2149e-07,
#          1.8245e-07, 1.8121e-08, 7.1702e-07, 1.2311e-08, 1.9655e-06, 1.3894e-05,
#          6.2262e-09]))

# %% [markdown]
# # Inference 5
# **Target:** kākāpō

# %%
img = Image.open(f'{img_path}/unknown_04.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown_04.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('kākāpō',
#  tensor(22),
#  tensor([9.2078e-07, 9.4574e-06, 2.1511e-07, 6.8818e-08, 2.6093e-08, 1.6481e-06,
#          1.2482e-06, 4.0917e-08, 6.0085e-08, 9.5484e-09, 1.1406e-06, 1.4901e-06,
#          6.0200e-07, 2.8841e-04, 1.6480e-05, 1.3848e-06, 1.6201e-07, 1.0003e-06,
#          4.1095e-04, 1.0321e-07, 2.7461e-07, 8.1867e-04, 9.9834e-01, 1.7622e-06,
#          6.2345e-06, 9.2438e-07, 5.1956e-07, 4.3698e-05, 1.7690e-06, 2.1083e-06,
#          3.1660e-07, 3.5508e-07, 1.7662e-06, 3.3033e-06, 3.0860e-07, 1.6638e-08,
#          1.6388e-06, 1.9375e-05, 4.6476e-06, 4.7403e-08, 1.7241e-06, 2.2928e-06,
#          2.9989e-07, 2.2552e-07, 1.2089e-07, 1.4036e-06, 6.5316e-07, 2.5903e-08,
#          7.4132e-06]))

# %% [markdown]
# # Inference 6
# **Target:** kea

# %%
img = Image.open(f'{img_path}/unknown_05.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x98>

# %%
model.predict(f'{img_path}/unknown_05.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('kea',
#  tensor(21),
#  tensor([2.0011e-05, 1.2892e-07, 6.5304e-09, 7.0413e-09, 1.6875e-08, 1.4832e-07,
#          2.3706e-05, 4.6348e-11, 6.9904e-09, 2.9253e-09, 3.7186e-08, 7.6708e-07,
#          3.4172e-07, 2.9331e-08, 6.0528e-07, 1.5268e-08, 2.2857e-08, 2.6972e-09,
#          6.6777e-07, 7.8122e-10, 2.5637e-08, 9.9992e-01, 7.0766e-07, 6.1071e-09,
#          4.7916e-08, 6.7201e-08, 7.6500e-06, 2.4990e-10, 2.9515e-09, 1.2665e-07,
#          9.9168e-08, 1.6010e-08, 1.2971e-08, 1.4946e-08, 1.6541e-08, 2.7889e-09,
#          2.3416e-05, 6.2814e-07, 5.5466e-07, 6.0460e-09, 2.9728e-08, 4.5356e-09,
#          4.0403e-09, 1.9535e-08, 2.3739e-07, 2.3839e-08, 3.8130e-08, 7.5594e-09,
#          4.0722e-08]))

# %% [markdown]
# # Inference 7
# **Target:** white cockatoo

# %%
img = Image.open(f'{img_path}/unknown_06.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown_06.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('white cockatoo',
#  tensor(46),
#  tensor([8.0296e-09, 2.3875e-10, 8.7819e-12, 1.1472e-05, 9.1357e-13, 1.3036e-09,
#          7.4210e-11, 6.2679e-12, 1.3259e-09, 9.6842e-09, 1.9628e-08, 7.4896e-10,
#          2.3762e-11, 8.4088e-11, 1.9143e-07, 2.6918e-10, 1.9184e-08, 1.4206e-10,
#          1.7579e-09, 1.1019e-08, 3.8987e-08, 6.8772e-09, 2.9248e-10, 1.2288e-12,
#          9.1031e-10, 4.4875e-10, 3.3439e-07, 1.1907e-10, 1.5408e-10, 1.6861e-10,
#          5.3813e-10, 5.4198e-11, 2.6796e-10, 1.1840e-11, 1.3152e-07, 2.5406e-09,
#          5.3236e-09, 3.7043e-07, 1.2200e-10, 6.5676e-09, 6.3088e-12, 3.7267e-09,
#          1.3117e-11, 2.2200e-08, 2.8132e-09, 1.5016e-10, 9.9999e-01, 1.4222e-11,
#          1.1649e-10]))

# %% [markdown]
# # Inference 8
# **Target:** rose-ringed parakeet

# %%
img = Image.open(f'{img_path}/unknown_07.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=102x128>

# %%
model.predict(f'{img_path}/unknown_07.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('rose-ringed parakeet',
#  tensor(37),
#  tensor([5.8965e-09, 2.0344e-07, 1.9985e-06, 2.9496e-09, 2.3840e-09, 1.2228e-07,
#          1.5719e-08, 5.2516e-10, 5.7610e-11, 2.1159e-07, 5.4478e-09, 2.3397e-09,
#          3.4075e-08, 8.1936e-05, 8.5539e-08, 8.7859e-09, 4.9882e-07, 3.9806e-06,
#          2.0634e-08, 1.6232e-07, 5.6268e-08, 4.8833e-08, 1.0690e-08, 4.1042e-07,
#          4.1739e-07, 7.5336e-09, 1.1229e-06, 1.3905e-05, 1.0021e-04, 4.4054e-08,
#          6.0924e-08, 3.0044e-06, 1.3029e-07, 8.8078e-07, 5.1717e-08, 1.3551e-06,
#          9.8679e-08, 9.9975e-01, 1.0033e-09, 1.1738e-08, 1.1290e-08, 1.9238e-08,
#          1.3309e-09, 1.5748e-06, 8.7684e-08, 3.4342e-05, 4.2292e-08, 6.2616e-09,
#          3.2656e-08]))

# %% [markdown]
# # Inference 9
# **Target:** palm cockatoo

# %%
img = Image.open(f'{img_path}/unknown_08.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=96x128>

# %%
model.predict(f'{img_path}/unknown_08.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('palm cockatoo',
#  tensor(26),
#  tensor([6.9346e-08, 1.1930e-09, 5.2063e-08, 2.7463e-09, 3.6257e-10, 3.2377e-13,
#          3.4439e-10, 1.0734e-11, 1.2212e-09, 8.3029e-10, 1.1522e-09, 4.3973e-10,
#          3.0382e-10, 6.0692e-09, 1.1514e-08, 6.1359e-12, 9.7326e-08, 7.4800e-11,
#          6.5319e-08, 1.0490e-08, 2.6905e-07, 2.2866e-08, 1.0620e-10, 1.0796e-07,
#          2.4570e-09, 1.8316e-11, 1.0000e+00, 5.2858e-10, 9.8298e-09, 1.4640e-10,
#          5.3599e-10, 1.9900e-08, 3.5563e-10, 8.2136e-09, 4.5947e-12, 1.5518e-08,
#          9.3217e-08, 8.5538e-09, 6.7872e-12, 1.3810e-10, 6.0736e-11, 1.6942e-08,
#          1.2020e-09, 1.7408e-08, 5.3364e-12, 1.1072e-09, 3.7046e-10, 7.6733e-09,
#          7.6426e-11]))

# %% [markdown]
# # Inference 10
# **Target:** Turquoise-fronted Amazon

# %%
img = Image.open(f'{img_path}/unknown_09.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/unknown_09.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('turquoise-fronted amazon',
#  tensor(44),
#  tensor([1.1395e-07, 5.2693e-08, 2.5287e-09, 5.0137e-08, 1.0897e-05, 1.8058e-06,
#          2.9012e-07, 2.1507e-07, 3.1790e-09, 1.0117e-06, 7.2487e-08, 2.7980e-08,
#          2.0777e-07, 1.8892e-08, 9.4947e-10, 1.6451e-06, 2.8542e-07, 2.8045e-06,
#          6.8032e-09, 2.4127e-07, 8.1662e-08, 1.4427e-08, 3.6311e-08, 2.6483e-09,
#          2.5297e-09, 2.8615e-03, 8.1536e-09, 1.2246e-07, 1.9108e-06, 8.9911e-08,
#          7.0840e-07, 7.9915e-08, 3.1736e-05, 3.9343e-06, 4.5722e-07, 4.0283e-07,
#          1.3517e-07, 1.1472e-07, 1.2041e-06, 4.6041e-09, 1.2112e-06, 2.5475e-08,
#          1.7131e-06, 3.8656e-07, 9.9574e-01, 4.2880e-07, 5.7446e-08, 1.5765e-06,
#          1.3337e-03]))

# %% [markdown]
# # Inference 11
# **Target:** yellow-headed amazon

# %%
img = Image.open(f'{img_path}/unknown_10.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x92>

# %%
model.predict(f'{img_path}/unknown_10.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('yellow-headed amazon',
#  tensor(48),
#  tensor([3.7245e-08, 1.1571e-07, 4.7486e-09, 6.9396e-09, 1.4801e-08, 3.1195e-07,
#          6.2091e-09, 2.7612e-08, 2.5578e-09, 1.0378e-07, 2.0976e-08, 1.4758e-10,
#          1.0385e-07, 1.2801e-06, 3.1447e-09, 3.6417e-07, 8.9751e-09, 6.1373e-07,
#          1.0017e-08, 3.5091e-08, 5.4497e-08, 2.6062e-09, 5.0171e-08, 9.3385e-09,
#          3.0227e-09, 2.8744e-05, 3.5815e-08, 2.1050e-08, 1.3636e-07, 1.6957e-09,
#          1.3005e-07, 3.1501e-09, 1.8123e-06, 8.0722e-08, 7.3782e-09, 6.4080e-08,
#          1.6117e-08, 1.8877e-07, 1.5548e-07, 3.3539e-09, 3.0281e-08, 5.5480e-09,
#          2.6023e-07, 1.5320e-07, 2.8499e-04, 4.3263e-07, 3.4822e-09, 6.6367e-08,
#          9.9968e-01]))

# %% [markdown]
# # Inference 12
# **Target:** yellow-collared macaws

# %%
img = Image.open(f'{img_path}/unknown_11.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
model.predict(f'{img_path}/unknown_11.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('yellow-collared macaws',
#  tensor(47),
#  tensor([4.5548e-07, 1.7312e-08, 6.6475e-06, 9.3177e-05, 2.1102e-06, 3.5182e-07,
#          1.4542e-05, 4.2246e-07, 1.5427e-05, 8.7522e-02, 5.5373e-08, 1.0129e-07,
#          4.7045e-06, 6.8639e-08, 5.5795e-08, 6.2091e-07, 3.1163e-05, 1.8874e-08,
#          2.8129e-06, 2.5070e-04, 1.2002e-05, 2.0739e-07, 1.5186e-08, 1.1470e-06,
#          1.3225e-06, 1.1252e-06, 3.3256e-07, 2.2012e-06, 1.8823e-06, 2.8216e-06,
#          5.5334e-09, 5.6482e-06, 3.3630e-09, 5.8365e-07, 5.5038e-08, 2.8805e-02,
#          3.4202e-07, 5.7735e-08, 5.2017e-06, 2.0555e-05, 1.8345e-08, 8.8533e-06,
#          1.2743e-07, 5.1543e-08, 3.3416e-06, 9.1058e-08, 1.4618e-07, 8.8318e-01,
#          1.6668e-08]))

# %% [markdown]
# # Inference 13
# **Target:** sun conure

# %%
img = Image.open(f'{img_path}/unknown_12.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x105>

# %%
model.predict(f'{img_path}/unknown_12.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('sun conure',
#  tensor(42),
#  tensor([9.4519e-09, 2.0165e-08, 9.2609e-09, 4.8421e-07, 1.7387e-09, 6.1092e-08,
#          2.5284e-07, 2.5035e-05, 3.6090e-05, 3.9699e-08, 1.1671e-07, 4.4686e-08,
#          7.3916e-09, 6.7101e-09, 2.9167e-09, 1.0096e-03, 8.1742e-06, 1.1504e-07,
#          2.6106e-08, 1.7916e-08, 4.2181e-08, 2.0609e-09, 3.7942e-08, 8.0704e-07,
#          1.8854e-10, 2.0565e-08, 2.5602e-08, 3.4109e-08, 5.4504e-08, 6.9402e-08,
#          1.3888e-07, 1.1550e-08, 8.6188e-08, 5.7656e-08, 3.2971e-09, 1.8377e-08,
#          8.8420e-09, 8.3312e-10, 8.5296e-09, 3.9723e-07, 9.6840e-07, 3.3263e-08,
#          9.9891e-01, 2.3191e-07, 1.7328e-07, 1.1910e-08, 5.9339e-10, 1.1231e-06,
#          7.5280e-06]))

# %% [markdown]
# # Inference 14
# **Target:** rainbow lorikeet

# %%
img = Image.open(f'{img_path}/unknown_13.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x91>

# %%
model.predict(f'{img_path}/unknown_13.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('rainbow lorikeet',
#  tensor(30),
#  tensor([9.3539e-08, 6.1021e-08, 5.1017e-06, 1.9551e-08, 5.8319e-07, 8.7372e-09,
#          5.1583e-10, 1.1732e-08, 2.0905e-07, 4.7720e-10, 2.7398e-09, 5.7139e-06,
#          3.3204e-06, 2.4742e-07, 7.9242e-09, 3.2817e-09, 3.3086e-10, 3.6167e-08,
#          9.6687e-10, 2.6340e-09, 1.4267e-08, 1.2931e-06, 1.0081e-08, 1.8146e-08,
#          4.3599e-10, 2.0388e-08, 4.5157e-09, 2.5444e-10, 4.4730e-08, 1.1559e-09,
#          9.9998e-01, 9.3592e-09, 2.4393e-09, 6.3007e-09, 2.0406e-06, 9.1180e-10,
#          3.8988e-08, 2.2816e-09, 1.7818e-06, 7.8805e-09, 2.5042e-09, 2.2732e-09,
#          1.2002e-07, 4.7967e-09, 1.0794e-08, 6.5431e-08, 2.8963e-09, 1.8096e-09,
#          2.6623e-08]))

# %% [markdown]
# # **Result: ALL OF THEM CORRECTLY CLASSIFIED**
