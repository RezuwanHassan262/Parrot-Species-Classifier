# %% [markdown]
# # **Extracting Classes from web**

# %%
import requests
import bs4
from bs4 import BeautifulSoup
from urllib.request import urlopen

import numpy as np
import pandas as pd
import os

# %%
url = "https://www.google.com/search?q=parrot+species&bih=955&biw=1920&hl=en&sxsrf=AB5stBgiHaMmZgUYv8e5-P9AKq-5UDlu7A%3A1689275741579&ei=XU2wZPH9Iu_b2roPtLe_oAY&ved=0ahUKEwixoITEsoyAAxXvrVYBHbTbD2QQ4dUDCA4&uact=5&oq=parrot+species&gs_lcp=Cgxnd3Mtd2l6LXNlcnAQAzIHCCMQigUQJzIHCCMQigUQJzIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEOgoIABBHENYEELADOgoILhCKBRCwAxBDOgYIABAWEB46CAgAEBYQHhAPSgQIQRgAUM0HWPURYN0TaAFwAXgAgAGoAYgBtwaSAQMwLjWYAQCgAQHAAQHIAQk&sclient=gws-wiz-serp"

#(requests.get(url, {}).text, "lxml") #taking the url as text and converting into lxml

# %%
url = "https://www.google.com/search?q=parrot+species&bih=955&biw=1920&hl=en&sxsrf=AB5stBgiHaMmZgUYv8e5-P9AKq-5UDlu7A%3A1689275741579&ei=XU2wZPH9Iu_b2roPtLe_oAY&ved=0ahUKEwixoITEsoyAAxXvrVYBHbTbD2QQ4dUDCA4&uact=5&oq=parrot+species&gs_lcp=Cgxnd3Mtd2l6LXNlcnAQAzIHCCMQigUQJzIHCCMQigUQJzIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEOgoIABBHENYEELADOgoILhCKBRCwAxBDOgYIABAWEB46CAgAEBYQHhAPSgQIQRgAUM0HWPURYN0TaAFwAXgAgAGoAYgBtwaSAQMwLjWYAQCgAQHAAQHIAQk&sclient=gws-wiz-serp"
web_page = bs4.BeautifulSoup(requests.get(url, {}).text, "lxml") #Extracting HTML of the static webpage
# web_page #The HTML code of the page

# %%
tables = web_page.find_all(name="div",attrs = {"class":"BNeawe s3v9rd AP7Wnd"}) #With class name


tables
# Out:
# [<div class="BNeawe s3v9rd AP7Wnd">Grey parrot</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Cockatiel</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Budgerigar</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Moluccan eclectus</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Hyacinth macaw</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Rose-ringed parakeet</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Blue-and-yellow macaw</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Scarlet macaw</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Monk parakeet</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Sulphur-crested cockatoo</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Sun conure</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Senegal parrot</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Rainbow lorikeet</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Blue-fronted amazon</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Burrowing parrot</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Red-crowned amazon</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Carolina parakeet</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Yellow-crowned amazon</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Lilac-crowned amazon</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Red-and-green macaw</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Cuban amazon</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">White cockatoo</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Thick-billed parrot</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Red-rumped parrot</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Golden parakeet</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Rosy-faced lovebird</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Puerto Rican ama...</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Yellow-faced parrot</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Orange-winged amazon</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Kākāpō</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Vernal hanging p...</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Hispaniolan amazon</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Saint Vincent a...</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Green parakeet</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Australian king parrot</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Palm cockatoo</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Orange-bellied parrot</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Kea</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Green rosella</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Yellow-naped amazon</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Blue-headed parrot</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Pacific parrotlet</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Chestnut-fronted macaw</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Yellow-headed amazon</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Galah</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Red-fan parrot</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Blue-crowned parakeet</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Crimson rosella</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Military macaw</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Blue lorikeet</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Golden-winged parakeet</div>,
#  <div class="BNeawe s3v9rd AP7Wnd"><div><div class="v9i61e"><div class="BNeawe s3v9rd AP7Wnd">Parrot species that are commonly kept as pets include conures, macaws, amazon parrots, cockatoos, greys, lovebirds, cockatiels, budgerigars, caiques, parakeets, ...</div></div><div class="v9i61e"><div class="BNeawe s3v9rd AP7Wnd"><span class="BNeawe"><a data-ved="2ahUKEwjhiKug4KSAAxX0qJUCHSM9A4AQ0gJ6BAgEE
div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Crimson rosella</div>,
#  <div class="BNeawe s3v9rd AP7Wnd">Eastern rosella</div>]

# %%
tables[0]
# Out:
# <div class="BNeawe s3v9rd AP7Wnd">Grey parrot</div>

# %%
parrots = []
for i in range(51):
  parrots.append(tables[i].text.lower())
  # print(tables[i].text)
  # print()

print()
print()
print()
print(parrots)
# Out:
# ['grey parrot', 'cockatiel', 'budgerigar', 'moluccan eclectus', 'hyacinth macaw', 'rose-ringed parakeet', 'blue-and-yellow macaw', 'scarlet macaw', 'monk parakeet', 'sulphur-crested cockatoo', 'sun conure', 'senegal parrot', 'rainbow lorikeet', 'blue-fronted amazon', 'burrowing parrot', 'red-crowned amazon', 'carolina parakeet', 'yellow-crowned amazon', 'lilac-crowned amazon', 'red-and-green macaw', 'cuban amazon', 'white cockatoo', 'thick-billed parrot', 'red-rumped parrot', 'golden parakeet', 'rosy-faced lovebird', 'puerto rican ama...', 'yellow-faced parrot', 'orange-winged amazon', 'kākāpō', 'vernal hanging p...', 'hispaniolan amazon', 'saint vincent a...', 'green parakeet', 'australian king parrot', 'palm cockatoo', 'orange-bellied parrot', 'kea', 'green rosella', 'yellow-naped amazon', 'blue-headed parrot', 'pacific parrotlet', 'chestnut-fronted macaw', 'yellow-headed amazon', 'galah', 'red-fan parrot', 'blue-crowned parakeet', 'crimson rosella', 'military macaw', 'blue lorikeet', 'golden-winged parakeet']

# %%
len(parrots)
# Out:
# 51

# %%
#Finding the number of incomplete names

c = 0
for i in parrots:
    if i[-3:] == "...":
        print(i)
        c += 1
print()
print(c)
# Out:
# puerto rican ama...
# vernal hanging p...
# saint vincent a...
#
# 3

# %%
#Completing the incomplete names


for i in parrots:
  if i[-3:] == "...":
    x = parrots.index(i)
    print(i, x)

    if i == "puerto rican ama...":
      parrots[parrots.index(i)] = parrots[parrots.index(i)].replace("puerto rican ama...", "puerto rican amazon")
      # print(parrots[x])
    elif i == "saint vincent a...":
      parrots[parrots.index(i)] = parrots[parrots.index(i)].replace("saint vincent a...", "saint vincent amazon")
      # print(parrots[x])
    elif i == "southern mealy am...":
      parrots[parrots.index(i)] = parrots[parrots.index(i)].replace("southern mealy am...", "southern mealy amazon")
      # print(parrots[x])
    elif i == "new caledonia...":
      parrots[parrots.index(i)] = parrots[parrots.index(i)].replace("new caledonia...", "new caledonian lorikeet")
      # print(parrots[x])
    elif i == "vernal hanging p...":
      parrots[parrots.index(i)] = parrots[parrots.index(i)].replace("vernal hanging p...", "vernal hanging parrot")
      # print(parrots[x])
    elif i == "eastern ground pa...":
      parrots[parrots.index(i)] = parrots[parrots.index(i)].replace("eastern ground pa...", "eastern ground parrot")
      # print(parrots[x])
# Out:
# puerto rican ama... 26
# vernal hanging p... 30
# saint vincent a... 32

# %%
for i in parrots:
  print(i)
# Out:
# grey parrot
# cockatiel
# budgerigar
# moluccan eclectus
# hyacinth macaw
# rose-ringed parakeet
# blue-and-yellow macaw
# scarlet macaw
# monk parakeet
# sulphur-crested cockatoo
# sun conure
# senegal parrot
# rainbow lorikeet
# blue-fronted amazon
# burrowing parrot
# red-crowned amazon
# carolina parakeet
# yellow-crowned amazon
# lilac-crowned amazon
# red-and-green macaw
# cuban amazon
# white cockatoo
# thick-billed parrot
# red-rumped parrot
# golden parakeet
# rosy-faced lovebird
# puerto rican amazon
# yellow-faced parrot
# orange-winged amazon
# kākāpō
# vernal hanging parrot
# hispaniolan amazon
# saint vincent amazon
# green parakeet
# australian king parrot
# palm cockatoo
# orange-bellied parrot
# kea
# green rosella
# yellow-naped amazon
# blue-headed parrot
# pacific parrotlet
# chestnut-fronted macaw
# yellow-headed amazon
# galah
# red-fan parrot
# blue-crowned parakeet
# crimson rosella
# military macaw
# blue lorikeet
# golden-winged parakeet

# %%
#Finding the number of incomplete names

for i in parrots:
  if i[-3:] == "...":
    print(i, parrots.index(i))

# %%
# for i in range(51):
#   print(tables[i].text)
#   print()

# %%
parrots.sort()
parrots
# Out:
# ['australian king parrot',
#  'blue-and-yellow macaw',
#  'blue-crowned parakeet',
#  'blue-headed parrot',
#  'blue-winged macaw',
#  'budgerigar',
#  'burrowing parrot',
#  'carolina parakeet',
#  'cockatiel',
#  'cuban amazon',
#  'galah',
#  'golden parakeet',
#  'green parakeet',
#  'green rosella',
#  'grey parrot',
#  'hyacinth macaw',
#  'kea',
#  'kākāpō',
#  'lilac-crowned amazon',
#  'moluccan eclectus',
#  'monk parakeet',
#  'orange-winged amazon',
#  'pacific parrotlet',
#  'palm cockatoo',
#  'puerto rican amazon',
#  'rainbow lorikeet',
#  'red-and-green macaw',
#  'red-crowned amazon',
#  'red-crowned parakeet',
#  'red-fan parrot',
#  'red-lored amazon',
#  'red-rumped parrot',
#  'red-shouldered macaw',
#  'red-tailed black cock...',
#  'rose-ringed parakeet',
#  'rosy-faced lovebird',
#  'saint vincent amazon',
#  'scarlet macaw',
#  'senegal parrot',
#  "spix's macaw",
#  'sulphur-crested cockatoo',
#  'sun conure',
#  'thick-billed parrot',
#  'timneh parrot',
#  'turquoise-fronted amazon',
#  'vernal hanging parrot',
#  'white cockatoo',
#  'yellow-crowned amazon',
#  'yellow-faced parrot',
#  'yellow-headed amazon',
#  'yellow-naped amazon']

# %%
# Total number of classes

len(parrots)
# Out:
# 51

# %% [markdown]
# # **Extracting some more classes from rest of the HTML code**

# %%
c = 0
rem = []
for i in tables[51:-4]:
  # print(i.text)
  # x = i.text.split(" · ")
  # print(x)
  # x = i.text.split(", ")
  # print(x)
  i = i.text.lower()
  x = i.split("""<span class="BNeawe">""")
  # print(x)

  for j in x:
    y = j.split(", ")
    # print(y)

    for k in y:
      z = k.split(" · ")
      #print(z)

      for a in z:
        if "cockatoo" in a or "parrot" in a:
          for p in parrots:
            if p not in a:
              rem.append(a)

  # print()


#print(rem)
rem = np.unique(rem)
print(rem)

# for i in rem:
#   print(i)

  # if i.text not in parrots:
  #   c += 1
  #   if c > 4:
  #     print(i.text)
# Out:
# ['1. african grey parrots' '1. amazon parrot' '2. caique parrot'
#  '2. cockatoos' '3. african grey parrots:' '4. cockatoo' '4. parrotlet'
#  '5. conure parrot' '6. eclectus parrot' '6. senegal parrot'
#  '8 top colorful parrot species' '8. eclectus parrots.'
#  '8. eclectus parrots.the 20 types of parrots to...' 'african grey parrot'
#  'amazon parrots' 'australian king parrot' 'blue headed parrot'
#  'burrowing parrot' 'cockatoos' 'eclectus parrots'
#  'greater vasa parrot\xa0...' 'list of top 15 parrot types:'
#  'parrot breeds'
#  'parrot species that are commonly kept as pets include conures' 'parrots'
#  'senegal parrot' 'species guides. african grey parrots'
#  'the 20 types of parrots to...'
#  'the many types of parrots ; small parrots. cockatiels. lovebirds ; medium parrots. caiques. small conures ; large parrots. african greys. amazons\xa0...'
#  'true parrots']

# %%
for i in rem:
  print(i)
# Out:
# 1. african grey parrots
# 1. amazon parrot
# 2. caique parrot
# 2. cockatoos
# 3. african grey parrots:
# 4. cockatoo
# 4. parrotlet
# 5. conure parrot
# 6. eclectus parrot
# 6. senegal parrot
# 8 top colorful parrot species
# 8. eclectus parrots.
# 8. eclectus parrots.the 20 types of parrots to...
# african grey parrot
# amazon parrots
# australian king parrot
# blue headed parrot
# burrowing parrot
# cockatoos
# eclectus parrots
# greater vasa parrot ...
# list of top 15 parrot types:
# parrot breeds
# parrot species that are commonly kept as pets include conures
# parrots
# senegal parrot
# species guides. african grey parrots
# the 20 types of parrots to...
# the many types of parrots ; small parrots. cockatiels. lovebirds ; medium parrots. caiques. small conures ; large parrots. african greys. amazons ...
# true parrots

# %%
newP = []
for i in rem:
  #print(i)

  if i in parrots: pass

  elif "true parrots" in i or "video" in i or i == "true parrots" or "guides" in i or "belong" in i: pass

  elif  "enicognathus ferrugineus" in i: newP.append("austral parakeet")

  elif ". " in i:
    x = i.split(". ")
    #print(x)
    for j in x:
      y = j.split(".")
      for k in y:
        if "true parrots" in k or "type" in k or "belong " in k or "species" in k or "simply" in k or "video" in k or k == "true parrots" : pass
        elif k not in parrots and k not in newP:

          try: k = int(k)
          except: newP.append(k)

  elif i[-6:] == 'parrot' or i[-8:] == 'cockatoo': newP.append(i)

  elif i[-3:] == '...' and i[:3] != 'the': newP.append(i[:-4])

  elif " ; " in i and i[-3:] == "..." :
    b = i.split(" ; ")
    # print("==============")
    # print(x)
    # print("==============")
    newP.append(b[0])

  # print()

# %%
for i in newP:
  print(i)
# Out:
# african grey parrots
# amazon parrot
# caique parrot
# cockatoos
# african grey parrots:
# cockatoo
# parrotlet
# conure parrot
# eclectus parrot
# eclectus parrots
#
# african grey parrot
# blue headed parrot
# greater vasa parrot
# cockatiels
# lovebirds ; medium parrots
# caiques
# small conures ; large parrots
# african greys
# amazons

# %%
for i in newP:
  if ";" in i:
    print(i)
    x = i.split(" ; ")
    print(x)
    newP[newP.index(i)] = newP[newP.index(i)].replace(i, x[0])
    print(newP[newP.index(x[0])])
# Out:
# lovebirds ; medium parrots
# ['lovebirds', 'medium parrots']
# lovebirds
# small conures ; large parrots
# ['small conures', 'large parrots']
# small conures

# %%
newP.sort()
for i in newP:
  print(i)
# Out:
# african grey parrot
# african grey parrots
# african grey parrots:
# african greys
# amazon parrot
# amazons
# blue headed parrot
# caique parrot
# caiques
# cockatiels
# cockatoo
# cockatoos
# conure parrot
# eclectus parrot
# eclectus parrots
# greater vasa parrot
# lovebirds
# parrotlet
# small conures

# %%
# Manually emoving some specific entries

for i in newP:

  if i == '':
    newP.remove(i)
  elif i == 'amazons\xa0':
    newP.remove(i)
  elif i == 'amazon':
    newP.remove(i)
  elif i == 'amazon parrot':
    newP.remove(i)
  elif i == 'amazon parrots':
    newP.remove(i)
  elif i == 'african grey parrots':
    newP.remove(i)
  elif i == 'african grey parrots:':
    newP.remove(i)
  elif i == 'african greys':
    newP.remove(i)
  elif i == 'african greys':
    newP.remove(i)
  elif i == 'companion parrot':
    newP.remove(i)
  elif i == 'true parrot':
    newP.remove(i)
  elif i == 'eclectus parrots':
    newP.remove(i)



newP
# Out:
# ['african grey parrot',
#  'blue headed parrot',
#  'caique parrot',
#  'caiques',
#  'cockatiels',
#  'cockatoo',
#  'cockatoos',
#  'conure parrot',
#  'eclectus parrot',
#  'greater vasa parrot',
#  'lovebirds',
#  'parrotlet',
#  'small conures']

# %% [markdown]
# # Final classes

# %%
# Final classes

parrtos = parrots.extend(newP)
parrots.sort()
parrots
# Out:
# ['african grey parrot',
#  'australian king parrot',
#  'blue headed parrot',
#  'blue-and-yellow macaw',
#  'blue-crowned parakeet',
#  'blue-headed parrot',
#  'blue-winged macaw',
#  'budgerigar',
#  'burrowing parrot',
#  'caique parrot',
#  'caiques',
#  'carolina parakeet',
#  'cockatiel',
#  'cockatiels',
#  'cockatoo',
#  'cockatoos',
#  'conure parrot',
#  'cuban amazon',
#  'eclectus parrot',
#  'galah',
#  'golden parakeet',
#  'greater vasa parrot',
#  'green parakeet',
#  'green rosella',
#  'grey parrot',
#  'hyacinth macaw',
#  'kea',
#  'kākāpō',
#  'lilac-crowned amazon',
#  'lovebirds',
#  'moluccan eclectus',
#  'monk parakeet',
#  'orange-winged amazon',
#  'pacific parrotlet',
#  'palm cockatoo',
#  'parrotlet',
#  'puerto rican amazon',
#  'rainbow lorikeet',
#  'red-and-green macaw',
#  'red-crowned amazon',
#  'red-crowned parakeet',
#  'red-fan parrot',
#  'red-lored amazon',
#  'red-rumped parrot',
#  'red-shouldered macaw',
#  'red-tailed black cock...',
#  'rose-ringed parakeet',
#  'rosy-faced lovebird',
#  'saint vincent amazon',
#  'scarlet macaw',
#  'senegal parrot',
#  'small conures',
#  "spix's macaw",
#  'sulphur-crested cockatoo',
#  'sun conure',
#  'thick-billed parrot',
#  'timneh parrot',
#  'turquoise-fronted amazon',
#  'vernal hanging parrot',
#  'white cockatoo',
#  'yellow-crowned amazon',
#  'yellow-faced parrot',
#  'yellow-headed amazon',
#  'yellow-naped amazon']

# %%
import numpy as np

parrots = np.array(parrots)
parrots = np.unique(parrots)
parrots
# Out:
# array(['african grey parrot', 'australian king parrot',
#        'blue headed parrot', 'blue-and-yellow macaw',
#        'blue-crowned parakeet', 'blue-headed parrot', 'blue-winged macaw',
#        'budgerigar', 'burrowing parrot', 'caique parrot', 'caiques',
#        'carolina parakeet', 'cockatiel', 'cockatiels', 'cockatoo',
#        'cockatoos', 'conure parrot', 'cuban amazon', 'eclectus parrot',
#        'galah', 'golden parakeet', 'greater vasa parrot',
#        'green parakeet', 'green rosella', 'grey parrot', 'hyacinth macaw',
#        'kea', 'kākāpō', 'lilac-crowned amazon', 'lovebirds',
#        'moluccan eclectus', 'monk parakeet', 'orange-winged amazon',
#        'pacific parrotlet', 'palm cockatoo', 'parrotlet',
#        'puerto rican amazon', 'rainbow lorikeet', 'red-and-green macaw',
#        'red-crowned amazon', 'red-crowned parakeet', 'red-fan parrot',
#        'red-lored amazon', 'red-rumped parrot', 'red-shouldered macaw',
#        'red-tailed black cock...', 'rose-ringed parakeet',
#        'rosy-faced lovebird', 'saint vincent amazon', 'scarlet macaw',
#        'senegal parrot', 'small conures', "spix's macaw",
#        'sulphur-crested cockatoo', 'sun conure', 'thick-billed parrot',
#        'timneh parrot', 'turquoise-fronted amazon',
#        'vernal hanging parrot', 'white cockatoo', 'yellow-crowned amazon',
#        'yellow-faced parrot', 'yellow-headed amazon',
#        'yellow-naped amazon'], dtype='<U24')

# %%
for i in parrots:
  print(i)
# Out:
# african grey parrot
# australian king parrot
# blue headed parrot
# blue-and-yellow macaw
# blue-crowned parakeet
# blue-headed parrot
# blue-winged macaw
# budgerigar
# burrowing parrot
# caique parrot
# caiques
# carolina parakeet
# cockatiel
# cockatiels
# cockatoo
# cockatoos
# conure parrot
# cuban amazon
# eclectus parrot
# galah
# golden parakeet
# greater vasa parrot
# green parakeet
# green rosella
# grey parrot
# hyacinth macaw
# kea
# kākāpō
# lilac-crowned amazon
# lovebirds
# moluccan eclectus
# monk parakeet
# orange-winged amazon
# pacific parrotlet
# palm cockatoo
# parrotlet
# puerto rican amazon
# rainbow lorikeet
# red-and-green macaw
# red-crowned amazon
# red-crowned parakeet
# red-fan parrot
# red-lored amazon
# red-rumped parrot
# red-shouldered macaw
# red-tailed black cock...
# rose-ringed parakeet
# rosy-faced lovebird
# saint vincent amazon
# scarlet macaw
# senegal parrot
# small conures
# spix's macaw
# sulphur-crested cockatoo
# sun conure
# thick-billed parrot
# timneh parrot
# turquoise-fronted amazon
# vernal hanging parrot
# white cockatoo
# yellow-crowned amazon
# yellow-faced parrot
# yellow-headed amazon
# yellow-naped amazon

# %%
parrots = list(parrots)

# %%
len(parrots)
# Out:
# 64

# %%
parrots
# Out:
# ['african grey parrot',
#  'australian king parrot',
#  'blue headed parrot',
#  'blue-and-yellow macaw',
#  'blue-crowned parakeet',
#  'blue-headed parrot',
#  'blue-winged macaw',
#  'budgerigar',
#  'burrowing parrot',
#  'caique parrot',
#  'caiques',
#  'carolina parakeet',
#  'cockatiel',
#  'cockatiels',
#  'cockatoo',
#  'cockatoos',
#  'conure parrot',
#  'cuban amazon',
#  'eclectus parrot',
#  'galah',
#  'golden parakeet',
#  'greater vasa parrot',
#  'green parakeet',
#  'green rosella',
#  'grey parrot',
#  'hyacinth macaw',
#  'kea',
#  'kākāpō',
#  'lilac-crowned amazon',
#  'lovebirds',
#  'moluccan eclectus',
#  'monk parakeet',
#  'orange-winged amazon',
#  'pacific parrotlet',
#  'palm cockatoo',
#  'parrotlet',
#  'puerto rican amazon',
#  'rainbow lorikeet',
#  'red-and-green macaw',
#  'red-crowned amazon',
#  'red-crowned parakeet',
#  'red-fan parrot',
#  'red-lored amazon',
#  'red-rumped parrot',
#  'red-shouldered macaw',
#  'red-tailed black cock...',
#  'rose-ringed parakeet',
#  'rosy-faced lovebird',
#  'saint vincent amazon',
#  'scarlet macaw',
#  'senegal parrot',
#  'small conures',
#  "spix's macaw",
#  'sulphur-crested cockatoo',
#  'sun conure',
#  'thick-billed parrot',
#  'timneh parrot',
#  'turquoise-fronted amazon',
#  'vernal hanging parrot',
#  'white cockatoo',
#  'yellow-crowned amazon',
#  'yellow-faced parrot',
#  'yellow-headed amazon',
#  'yellow-naped amazon']

# %% [markdown]
# **Final Classes**

# %%
for i in range(0, len(parrots)):
  print(f"{i+1}. {parrots[i]}")
# Out:
# 1. african grey parrot
# 2. australian king parrot
# 3. blue headed parrot
# 4. blue-and-yellow macaw
# 5. blue-crowned parakeet
# 6. blue-headed parrot
# 7. blue-winged macaw
# 8. budgerigar
# 9. burrowing parrot
# 10. caique parrot
# 11. caiques
# 12. carolina parakeet
# 13. cockatiel
# 14. cockatiels
# 15. cockatoo
# 16. cockatoos
# 17. conure parrot
# 18. cuban amazon
# 19. eclectus parrot
# 20. galah
# 21. golden parakeet
# 22. greater vasa parrot
# 23. green parakeet
# 24. green rosella
# 25. grey parrot
# 26. hyacinth macaw
# 27. kea
# 28. kākāpō
# 29. lilac-crowned amazon
# 30. lovebirds
# 31. moluccan eclectus
# 32. monk parakeet
# 33. orange-winged amazon
# 34. pacific parrotlet
# 35. palm cockatoo
# 36. parrotlet
# 37. puerto rican amazon
# 38. rainbow lorikeet
# 39. red-and-green macaw
# 40. red-crowned amazon
# 41. red-crowned parakeet
# 42. red-fan parrot
# 43. red-lored amazon
# 44. red-rumped parrot
# 45. red-shouldered macaw
# 46. red-tailed black cock...
# 47. rose-ringed parakeet
# 48. rosy-faced lovebird
# 49. saint vincent amazon
# 50. scarlet macaw
# 51. senegal parrot
# 52. small conures
# 53. spix's macaw
# 54. sulphur-crested cockatoo
# 55. sun conure
# 56. thick-billed parrot
# 57. timneh parrot
# 58. turquoise-fronted amazon
# 59. vernal hanging parrot
# 60. white cockatoo
# 61. yellow-crowned amazon
# 62. yellow-faced parrot
# 63. yellow-headed amazon
# 64. yellow-naped amazon

# %%
#Removing erroneous classes

parrots.remove('grey parrot')
parrots.remove('cockatiels')
parrots.remove('cockatoo')

# %%
len(parrots)
# Out:
# 60

# %%
parrots = ['african grey parrot',
 'australian king parrot',
 'blue headed parrot',
 'blue-and-yellow macaw',
 'blue-crowned parakeet',
 'blue-headed parrot',
 'blue-winged macaw',
 'budgerigar',
 'burrowing parrot',
 'caique parrot',
 'caiques',
 'carolina parakeet',
 'cockatoos',
 'conure parrot',
 'cuban amazon',
 'eclectus parrot',
 'galah',
 'golden parakeet',
 'greater vasa parrot',
 'green parakeet',
 'green rosella',
 "hooded parrot",
 'hyacinth macaw',
 'kea',
 'kākāpō',
 'lilac-crowned amazon',
 'lovebirds',
 'moluccan eclectus',
 'monk parakeet',
 'orange-winged amazon',
 'pacific parrotlet',
 'palm cockatoo',
 'parrotlet',
 'puerto rican amazon',
 'rainbow lorikeet',
 'red-and-green macaw',
 'red-crowned amazon',
 'red-crowned parakeet',
 'red-fan parrot',
 'red-lored amazon',
 'red-rumped parrot',
 'red-shouldered macaw',
 'red-tailed black cock...',
 'rose-ringed parakeet',
 'rosy-faced lovebird',
 'saint vincent amazon',
 'scarlet macaw',
 'senegal parrot',
 'small conures',
 "spix's macaw",
 'sulphur-crested cockatoo',
 'sun conure',
 'thick-billed parrot',
 'timneh parrot',
 'turquoise-fronted amazon',
 'vernal hanging parrot',
 'white cockatoo',
 'yellow-crowned amazon',
 'yellow-faced parrot',
 'yellow-headed amazon',
 'yellow-naped amazon']

# %%
parrots = [
 #'blue lorikeet',
 #'cockatiels',
 #'pink cockatoos',
 #'white cockatoos',
 #'moluccan eclectus',
# 'rainbow lorikeet',
#  'Thick-Billed parrot',
#  'Maroon fronted Parrot'
 #'small conures',
 #"spixs macaw",
#  "great hanging parrot",
#  "plum-headed parakeet",
#  "catalina macaw",
# "hahn's macaws",
# "illiger's macaws",
# "severe macaws",
# "yellow-collared macaws",
# "great green macaw",
# "crimson rosella",
# "red-breasted parakeet",
#'Hooded parrot'
 ]

# %% [markdown]
# # **Downloading pictures from web**

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
os.chdir("/content/drive/MyDrive/MCBD/")
x = !ls
x

# %%
# %cd /content/drive/MyDrive/MCBD/
# Out:
# /content

# %%
# !pip install -Uqq fastai
# !pip install -Uqq fastbook

# %%
import fastai
import fastbook
from fastai import *
from fastai.vision.all import *
from fastai.vision.widgets import *
from fastbook import *
from urllib.request import urlopen
import os

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
bs = 32 # batch size
version = 1


global parrot_species
global dp

# %% [markdown]
# **Download Images from Browser**
#
# You can download images from Google Image Search and Bing Image Search. You can try it out in your own time. You might need to build a scraper or use their API.
#
# For ease, we are going to use DuckDuckGo Image Search.
#
# Good news! Fastai has a function to do this for us.

# %%
doc(search_images_ddg)

# %%
doc(search_images_bing)

# %%
def create_dir(base,ext):
    _path=os.path.join(base,ext)
    if not os.path.exists(_path):
        os.mkdir(_path)
    return _path


def downloading_images(images, parrot_species):

    #failed_urls = []
    for i in range(0,len(images)):
        try:
            download_url(images[i], f"{dp}/{parrot_species}_{i}.jpg",show_progress = False)
        except:
            continue


def totalFile(parrot_species):
    allFiles = os.listdir(f"/content/drive/MyDrive/MCBD/{parrot_species}/")
    return allFiles



def deleting_corrupt_files(allFiles,parrot_species):

    for i in allFiles:

        path = f"/content/drive/MyDrive/MCBD/{parrot_species}/{i}"
        try:
            im = Image.open(path)
            im.verify()
        except:
            os.remove(f"/content/drive/MyDrive/MCBD/{parrot_species}/{i}")

# %%
import os
# %cd /content/drive/MyDrive/MCBD
# print(os.getcwd())
# Out:
# /content

# %%
import time


for j in range(0,len(parrots)):
  i = parrots[j]
  dp=create_dir(os.getcwd(),f"{i}")
  images = search_images_ddg(i, max_images=200)
  species_list[i] = len(images)

  start = time.time()

  downloading_images(images, i)
  allFiles = totalFile(i)
  before = len(allFiles)
  deleting_corrupt_files(allFiles,i)
  end = time.time()

  t = end - start
  seconds = t % (24 * 3600)
  hour = seconds // 3600
  seconds %= 3600
  minutes = seconds // 60
  seconds %= 60
  tot = f"{minutes} Minutes {seconds} Seconds"



  print(f"{i}: {len(os.listdir(dp))} | Before : After = {before} : {len(os.listdir(dp))} | Total time = {tot} | Status: Done")
  print("===========================")
  time.sleep(10)
# Out:
# catalina macaw: 181 | Before : After = 197 : 181 | Total time = 1.0 Minutes 44.33090329170227 Seconds | Status: Done
# ===========================
# hahn's macaws: 191 | Before : After = 198 : 191 | Total time = 1.0 Minutes 38.56346869468689 Seconds | Status: Done
# ===========================
# illiger's macaws: 178 | Before : After = 188 : 178 | Total time = 1.0 Minutes 17.387468338012695 Seconds | Status: Done
# ===========================
# severe macaws: 187 | Before : After = 195 : 187 | Total time = 1.0 Minutes 46.66000413894653 Seconds | Status: Done
# ===========================
# yellow-collared macaws: 168 | Before : After = 178 : 168 | Total time = 1.0 Minutes 19.996881246566772 Seconds | Status: Done
# ===========================
# great green macaw: 194 | Before : After = 196 : 194 | Total time = 1.0 Minutes 23.62975263595581 Seconds | Status: Done
# ===========================
# crimson rosella: 180 | Before : After = 192 : 180 | Total time = 1.0 Minutes 50.17011094093323 Seconds | Status: Done
# ===========================
# red-breasted parakeet: 196 | Before : After = 200 : 196 | Total time = 1.0 Minutes 30.45015788078308 Seconds | Status: Done
# ===========================

# %%
data_path = "C:/Users/MD. REZUWAN HASAN/Desktop/Jupyter Notebooks/Master Course BD/Week 9/Own Practice/images"

# %%
image_counts = get_image_files(data_path)
image_counts

# %%
doc(get_image_files)

# %% [markdown]
# # Creating DataBlocks

# %%
version = 2

dblock = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,                        # get_image_files returns a list of all images in that path recursively by default
    splitter=RandomSplitter(valid_pct=0.1, seed=42),  # getting 90-10 train-validation split
    get_y=parent_label,                               # taking the folder name as labels
    item_tfms=Resize(128))                            # resizing to get the image of same shape

# %%
dls = dblock.dataloaders(data_path,bs=bs)             # setting up batch size for efficient GPU use

# %%
dls.train.show_batch(max_n=16, nrows=2)

# %%
dls.valid.show_batch(max_n=16, nrows=2)

# %% [markdown]
# # **Data Augmentation**

# %%
dblock = dblock.new(item_tfms=Resize(128, ResizeMethod.Squish)) # Squishing the whole image into (128 x 128) size
dls = dblock.dataloaders(data_path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
dblock = dblock.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros')) # Padding the extra spaced the whole image into (128 x 128) size without squishing
dls = dblock.dataloaders(data_path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
dblock = dblock.new(item_tfms=RandomResizedCrop(128, min_scale=0.3)) # Randomly cropping, cutting, resizing, coloring parts of image into (128 x 128) size
dls = dblock.dataloaders(data_path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
doc(aug_transforms) # aug_transforms is used for image data augmentation
# Out:
# aug_transforms(mult: 'float' = 1.0, do_flip: 'bool' = True, flip_vert: 'bool' = False, max_rotate: 'float' = 10.0, min_zoom: 'float' = 1.0, max_zoom: 'float' = 1.1, max_lighting: 'float' = 0.2, max_warp: 'float' = 0.2, p_affine: 'float' = 0.75, p_lighting: 'float' = 0.75, xtra_tfms: 'list' = None, size: 'int | tuple' = None, mode: 'str' = 'bilinear', pad_mode='reflection', align_corners=True, batch=False, min_scale=1.0)
# Utility func to easily create a list of flip, rotate, zoom, warp, lighting transforms.
#
# To get a prettier result with hyperlinks to source code and documentation, install nbdev: pip install nbdev

# %%
# RandomResizedCrop crops images randomly and create copies so that we don't miss out anything


dblock = dblock.new(item_tfms=RandomResizedCrop(224, min_scale=0.5), batch_tfms=aug_transforms())
dls = dblock.dataloaders(data_path)
dls.train.show_batch(max_n=8, nrows=2)

# %% [markdown]
# # Saving data loader model

# %%
torch.save(dls, f"parrot_dataloader_v{version}.pkl") #Saving data loader model
